# %%
# !pip install kfp

# %%
pip install kfp[kubernetes] --pre
# Out:
# Requirement already satisfied: kfp[kubernetes] in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (2.7.0)
# Requirement already satisfied: click<9,>=8.0.0 in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (from kfp[kubernetes]) (8.1.3)
# Requirement already satisfied: docstring-parser<1,>=0.7.3 in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (from kfp[kubernetes]) (0.16)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (from kfp[kubernetes]) (2.19.0)
# Requirement already satisfied: google-auth<3,>=1.6.1 in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (from kfp[kubernetes]) (2.29.0)
# Requirement already satisfied: google-cloud-storage<3,>=2.2.1 in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (from kfp[kubernetes]) (2.16.0)
# Requirement already satisfied: kfp-pipeline-spec==0.3.0 in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (from kfp[kubernetes]) (0.3.0)
# Requirement already satisfied: kfp-server-api<2.1.0,>=2.0.0 in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (from kfp[kubernetes]) (2.0.5)
# Requirement already satisfied: kubernetes<27,>=8.0.0 in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (from kfp[kubernetes]) (26.1.0)
# Requirement already satisfied: protobuf<5,>=4.21.1 in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (from kfp[kubernetes]) (4.23.3)
# Requirement already satisfied: PyYAML<7,>=5.3 in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (from kfp[kubernetes]) (6.0.1)
# Requirement already satisfied: requests-toolbelt<1,>=0.8.0 in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (from kfp[kubernetes]) (0.10.1)
# Requirement already satisfied: tabulate<1,>=0.8.6 in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (from kfp[kubernetes]) (0.9.0)
# Requirement already satisfied: urllib3<2.0.0 in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (from kfp[kubernetes]) (1.26.18)
# Requirement already satisfied: kfp-kubernetes<2 in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (from kfp[kubernetes]) (1.2.0)
# Requirement already satisfied: colorama in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (from click<9,>=8.0.0->kfp[kubernetes]) (0.4.6)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->kfp[kubernetes]) (1.63.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->kfp[kubernetes]) (1.23.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->kfp[kubernetes]) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.1->kfp[kubernetes]) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.1->kfp[kubernetes]) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.1->kfp[kubernetes]) (4.9)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (from google-cloud-storage<3,>=2.2.1->kfp[kubernetes]) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.6.0 in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (from google-cloud-storage<3,>=2.2.1->kfp[kubernetes]) (2.7.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (from google-cloud-storage<3,>=2.2.1->kfp[kubernetes]) (1.5.0)
# Requirement already satisfied: six>=1.10 in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (from kfp-server-api<2.1.0,>=2.0.0->kfp[kubernetes]) (1.16.0)
# Requirement already satisfied: certifi in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (from kfp-server-api<2.1.0,>=2.0.0->kfp[kubernetes]) (2023.5.7)
# Requirement already satisfied: python-dateutil in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (from kfp-server-api<2.1.0,>=2.0.0->kfp[kubernetes]) (2.8.2)
# Requirement already satisfied: setuptools>=21.0.0 in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (from kubernetes<27,>=8.0.0->kfp[kubernetes]) (63.2.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (from kubernetes<27,>=8.0.0->kfp[kubernetes]) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (from kubernetes<27,>=8.0.0->kfp[kubernetes]) (2.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.1->kfp[kubernetes]) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->kfp[kubernetes]) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->kfp[kubernetes]) (3.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages (from requests-oauthlib->kubernetes<27,>=8.0.0->kfp[kubernetes]) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip show kfp
# Out:
# Name: kfp
# Version: 2.7.0
# Summary: Kubeflow Pipelines SDK
# Home-page: https://github.com/kubeflow/pipelines
# Author: The Kubeflow Authors
# Author-email:
# License:
# Location: c:\users\bhavl\appdata\local\programs\python\python310\lib\site-packages
# Requires: click, docstring-parser, google-api-core, google-auth, google-cloud-storage, kfp-pipeline-spec, kfp-server-api, kubernetes, protobuf, PyYAML, requests-toolbelt, tabulate, urllib3
# Required-by: kfp-kubernetes

# %%
import kfp
import kfp.components as comp
import requests
import kfp.dsl as dsl
from kfp.dsl import pipeline
from kfp import kubernetes

# %%
@dsl.component(base_image = 'python:3.10',packages_to_install=['pandas'])
# @dsl.component.use_cache(False)
def prepare_data():
    import os
    import pandas as pd
    # os.mkdir("C:/Users/bhavl/Downloads/IRIS/data")
    # os.makedirs("data", exist_ok=True)
    print("Inside data ")
    df = pd.read_csv("https://raw.githubusercontent.com/TripathiAshutosh/dataset/main/iris.csv")
    df = df.dropna()
    
    df.to_csv(f'data/final_data.csv',index = False)
    print("data saved in csv format")

# %%
@dsl.component(base_image= 'python:3.10',packages_to_install=['pandas','numpy','scikit-learn'])
def train_test_split():

    import pandas as pd
    import numpy as np
    from sklearn.model_selection import train_test_split
    print("seperating data into test train")
    final_data = pd.read_csv(f'data/final_data.csv')
    target_column = 'class'
    X = final_data.loc[:,final_data.columns != target_column]
    y = final_data.loc[:,final_data.columns==target_column]
    X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,stratify = y,random_state = 47)
    np.save(f'data/X_train.npy',X_train)
    np.save(f'data/X_test.npy',X_test)
    np.save(f'data/y_train.npy',y_train)
    np.save(f'data/y_test.npy',y_test)

    print("training data")
    print("/n")
    print(X_train)

    print("test data")
    print("/n")
    print(X_test)

# %%
@dsl.component(base_image = 'python:3.10',packages_to_install=['pandas','numpy','scikit-learn'])
def train_basic_classifier():
    import pandas as pd
    import numpy as np
    from sklearn.linear_model import LogisticRegression
    X_train = np.load(f'data/X_train.npy',allow_pickle=True)
    y_train = np.load(f'data/y_train.npy',allow_pickle=True)
    classifier = LogisticRegression(max_iter = 500)
    classifier.fit(X_train,y_train)
    import pickle
    with open(f'data/model.pkl','wb') as f:
        pickle.dump(classifier,f)
    print("LOGISTIC REGRESSION TRAINED")

# %%
@dsl.component(base_image = 'python:3.10',packages_to_install=['pandas','numpy','scikit-learn'])
def test_on_data():
    import pandas as pd
    import numpy as np
    import pickle
    with open(f'data/model.pkl','rb') as f:
        l_model = pickle.load(f)
    X_test = np.load(f'data/X_test.npy',allow_pickle=True)
    y_pred = l_model.predict(X_test)
    
    
    np.save(f'data/y_pred.npy',y_pred)
    
    print("Prediction Completed")
    print(y_pred)

# %%
@dsl.component(base_image = 'python:3.10',packages_to_install=['pandas','numpy','scikit-learn'])
def predict_prob_on_test_data():
    import pandas as pd
    import numpy as np
    import pickle
    print("Inside predict_prob_on_test_data component")
    with open(f'data/model.pkl','rb') as f:
        logistic_reg_model = pickle.load(f)
    X_test = np.load(f'data/X_test.npy',allow_pickle=True)
    y_pred_prob = logistic_reg_model.predict_proba(X_test)
    np.save(f'data/y_pred_prob.npy', y_pred_prob)
    
    print("\nPredicted Probabilities")
    print("\n")
    print(y_pred_prob)

# %%
@dsl.component(base_image = 'python:3.10',packages_to_install=['pandas','numpy','scikit-learn'])
def get_metrics():
    import subprocess
    subprocess.run(['pip', 'install', 'pandas','numpy', 'scikit-learn'])
    import pandas as pd
    import numpy as np
    from sklearn.metrics import accuracy_score , precision_score,recall_score,log_loss
    from sklearn import metrics
    y_test = np.load(f'data/y_test.npy',allow_pickle=True)
    y_pred = np.load(f'data/y_pred.npy',allow_pickle=True)
    y_pred_prob = np.load(f'data/y_pred_prob.npy',allow_pickle=True)
    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred,average='micro')
    recall = recall_score(y_test, y_pred,average='micro')
    entropy = log_loss(y_test, y_pred_prob)
    acc_score = accuracy_score(y_test,y_pred)
    log = log_loss(y_test,y_pred_prob)
    print("\n Model Metrics:", {'accuracy': round(acc, 2), 'precision': round(prec, 2), 'recall': round(recall, 2), 'entropy': round(entropy, 2)})

# %%
@pipeline(name='iris-pipeline', description='Pipeline to prepare Iris dataset.')
def iris_pipeline(data_path: str):
    vop = kubernetes.CreatePVC(
        # can also use pvc_name instead of pvc_name_suffix to use a pre-existing PVC
        pvc_name_suffix='-my-pvc',
        access_modes=['ReadWriteMany'],
        size='1Gi',
        storage_class_name='standard',
        
    )
    
    prepare_iris_task = prepare_data()
    prepare_iris_task.set_caching_options(False)
    kubernetes.mount_pvc(
        prepare_iris_task,
        pvc_name=vop.outputs['name'],
        mount_path='/data',
    )
    split_data = train_test_split().after(prepare_iris_task)
    split_data.set_caching_options(False)
    kubernetes.mount_pvc(
        split_data,
        pvc_name=vop.outputs['name'],
        mount_path='/data',
    )
    classifier_training = train_basic_classifier().after(split_data)
    classifier_training.set_caching_options(False)
    test = test_on_data().after(classifier_training)
    test.set_caching_options(False)
    proba = predict_prob_on_test_data().after(test)
    proba.set_caching_options(False)
    evaluate = get_metrics().after(proba)
    evaluate.set_caching_options(False)
    
    
    kubernetes.mount_pvc(
        classifier_training,
        pvc_name=vop.outputs['name'],
        mount_path='/data',
    )
    kubernetes.mount_pvc(
        test,
        pvc_name=vop.outputs['name'],
        mount_path='/data',
    )
    kubernetes.mount_pvc(
        proba,
        pvc_name=vop.outputs['name'],
        mount_path='/data',
    )
    kubernetes.mount_pvc(
        evaluate,
        pvc_name=vop.outputs['name'],
        mount_path='/data',
    )
    # prepare_iris_task.execution_options.caching_strategy.max_cache_staleness = 'P0D'
    # split_data.execution_options.caching_strategy.max_cache_staleness = 'P0D'
    # classifier_training.execution_options.caching_strategy.max_cache_staleness = 'P0D'
    # test.execution_options.caching_strategy.max_cache_staleness = 'P0D'
    # proba.execution_options.caching_strategy.max_cache_staleness = 'P0D'
    # evaluate.execution_options.caching_strategy.max_cache_staleness = 'P0D'

# %%
# pvc1 = kubernetes.CreatePVC(
#         # can also use pvc_name instead of pvc_nstrategy.max_cache_staleness = 'P0D'
#     evaluate.execution_options.caching_ame_suffix to use a pre-existing PVC
#         pvc_name_suffix='-my-pvc',
#         access_modes=['ReadWriteOnce'],
#         size='5Gi',
#         storage_class_name='standard',
#     )

# %%
kfp.compiler.Compiler().compile(
    pipeline_func=iris_pipeline,
    package_path='./iris_pipeline.yaml'
)
